# %% [markdown]
# #### COMSAR Turorial

# %% [markdown]
# # Loading Timbre Track feature files

# %% [markdown]
# In order to use this notebook, you first have to export a set of feature files from ESRA.
# If you haven nott, go to [ESRA](https://esra.fbkultur.uni-hamburg.de/) create a new selection
# add some titles to it, and export their audio features.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Load features from ESRA

# %% [markdown]
# ESRA Timbre Track feature files are simply csv files. Rows correspond to the $n$th STFT segment. Columns represent features.

# %%
raw_515 = pd.read_csv('../data/515-timbre.csv')
raw_515
# Out:
#        https://esra.fbkultur.uni-hamburg.de/explore/view?entity_id=515  \
# 0                                                      0
# 1                                                      1
# 2                                                      2
# 3                                                      3
# 4                                                      4
# ...                                                  ...
# 15219                                              15219
# 15220                                              15220
# 15221                                              15221
# 15222                                              15222
# 15223                                              15223
#
#           centroid       spread  skewness  kurtosis   loudness  sharpness  \
# 0      9983.942910  3718.935397 -0.744758  2.588002  65.542956   0.054649
# 1      9805.327623  4244.812836 -0.881107  2.553325  65.037413   0.021519
# 2      9203.276384  4440.022020 -0.626652  2.153447  65.028410   0.020421
# 3      8881.367429  4512.140976 -0.382792  1.754592  65.148284   0.023020
# 4      7879.407845  3866.439516 -0.016991  1.916608  65.705151   0.044893
# ...            ...          ...       ...       ...        ...        ...
# 15219  6878.016265  3984.745093  0.348447  1.957656  65.355012   0.026131
# 15220  8187.715794  4209.887036 -0.205816  1.820182  65.102992   0.022144
# 15221  8866.021319  4239.620564 -0.335393  1.820388  65.170248   0.026088
# 15222  9636.780512  3882.403590 -0.662754  2.376123  64.924752   0.024321
# 15223  8753.577956  4256.748491 -0.340856  1.985632  65.122151   0.021646
#
#        roughness      flux
# 0       0.000064  0.322574
# 1       0.000011  0.134093
# 2       0.000010  0.730260
# 3       0.000013  2.856374
# 4       0.000060  0.584241
# ...          ...       ...
# 15219   0.000021  0.578096
# 15220   0.000014  0.680125
# 15221   0.000018  0.641975
# 15222   0.000014  0.522111
# 15223   0.000011  1.167137
#
# [15224 rows x 9 columns]

# %% [markdown]
# ## 2. Feature selection

# %% [markdown]
# Selction of features is crucial for neural network training. Which features you use depends on you and your goals. Also, the SOM cannot (easily) learn time series data. Hence, you have to aggregate the time dimension.

# %% [markdown]
# ### 2.1 Take only certain features

# %%
my_features = ['centroid', 'roughness']
raw_515[my_features]
# Out:
#           centroid  roughness
# 0      9983.942910   0.000064
# 1      9805.327623   0.000011
# 2      9203.276384   0.000010
# 3      8881.367429   0.000013
# 4      7879.407845   0.000060
# ...            ...        ...
# 15219  6878.016265   0.000021
# 15220  8187.715794   0.000014
# 15221  8866.021319   0.000018
# 15222  9636.780512   0.000014
# 15223  8753.577956   0.000011
#
# [15224 rows x 2 columns]

# %% [markdown]
# ### 2.2 Take only certain STFT segments

# %%
start = 20
stop = 100
step = 5
my_segments = slice(start, stop, step)
raw_515.iloc[my_segments]
# Out:
#     https://esra.fbkultur.uni-hamburg.de/explore/view?entity_id=515  \
# 20                                                 20
# 25                                                 25
# 30                                                 30
# 35                                                 35
# 40                                                 40
# 45                                                 45
# 50                                                 50
# 55                                                 55
# 60                                                 60
# 65                                                 65
# 70                                                 70
# 75                                                 75
# 80                                                 80
# 85                                                 85
# 90                                                 90
# 95                                                 95
#
#         centroid       spread  skewness  kurtosis   loudness  sharpness  \
# 20  10784.393442  3463.970148 -1.068177  3.431734  65.319716   0.053023
# 25   8349.881147  4114.936646 -0.182253  1.742108  65.645011   0.044125
# 30   8182.244923  4645.318724 -0.253286  1.701299  65.075039   0.017986
# 35   9039.108290  4293.150636 -0.768592  2.264628  65.040040   0.018678
# 40   8800.271448  4303.346504 -0.363012  1.864678  65.348445   0.030777
# 45   9150.418601  4576.455830 -0.694357  2.091417  64.898010   0.015661
# 50  10170.135786  3745.373725 -0.859136  2.852902  65.257716   0.038051
# 55  10327.159526  3632.650515 -0.923328  3.036293  65.354458   0.046754
# 60   8898.491855  4404.858012 -0.354163  1.798745  65.195749   0.027105
# 65   9226.562308  4571.146966 -0.556022  1.967588  64.901857   0.017318
# 70   7567.575063  4070.754690  0.094706  1.755929  65.842377   0.053464
# 75  10451.569734  3731.252466 -1.008679  3.122696  65.208595   0.035755
# 80  10143.230704  3952.441127 -0.916049  2.853436  65.316100   0.035931
# 85   7138.159531  4320.768347  0.067122  1.611724  65.500258   0.025620
# 90   8075.519609  4851.629966 -0.303512  1.683412  65.036095   0.015134
# 95   8675.073145  4667.086032 -0.438100  1.903987  65.053592   0.018813
#
#     roughness      flux
# 20   0.000057  1.066819
# 25   0.000048  2.738632
# 30   0.000008  0.520296
# 35   0.000010  0.072892
# 40   0.000022  0.113309
# 45   0.000007  0.271658
# 50   0.000030  6.407647
# 55   0.000047  4.822905
# 60   0.000018  0.649228
# 65   0.000007  0.162573
# 70   0.000082  0.499084
# 75   0.000026  0.274662
# 80   0.000028  4.571583
# 85   0.000022  3.315911
# 90   0.000007  2.715892
# 95   0.000009  0.349120

# %% [markdown]
# ### 2.3 Aggregate over time

# %% [markdown]
# Choose a form of aggregation, like mean value or standard deviation.

# %%
features = ['centroid', 'spread', 'roughness', 'flux']
feat_515 = raw_515[features].iloc[20:]    # 20: means from segment 20 till the end
feat_515 = feat_515.mean().to_numpy()

# %%
feat_515    # This is how a single title is presented to the SOM.
# Out:
# array([1.91478845e+03, 2.11132686e+03, 1.57729118e-03, 2.57756297e+00])

# %% [markdown]
# ## 3. Repeat

# %% [markdown]
# Choose a method and Repeat the above steps for all your csv files. Then, concatenate the features to a (big) SOM feature matrix (sfm).

# %%
# dummy data just for the example
feat_516 = np.random.rand(1, 4)
feat_517 = np.random.rand(1, 4)

# %%
feat_matrix = np.vstack((feat_515, feat_516, feat_517))
feat_matrix
# Out:
# array([[1.91478845e+03, 2.11132686e+03, 1.57729118e-03, 2.57756297e+00],
#        [1.14007368e-01, 2.30311383e-01, 1.00486885e-02, 4.90907724e-01],
#        [2.00552648e-01, 8.69712500e-01, 6.22862326e-01, 1.70603317e-01]])

# %% [markdown]
# It is good practice to convert the raw sfm array to a dataframe in order to retain information about the included features and songs.

# %%
song_names = ['Song1', 'Song2', 'SOng3']
sfm = pd.DataFrame(feat_matrix, index=song_names, columns=features)

# %%
sfm
# Out:
#           centroid       spread  roughness      flux
# Song1  1914.788445  2111.326855   0.001577  2.577563
# Song2     0.114007     0.230311   0.010049  0.490908
# SOng3     0.200553     0.869713   0.622862  0.170603

# %% [markdown]
# ## 4. Save your work

# %% [markdown]
# Once you've finished constructing the feature matrix it is usefull store you work for later reuse.
# Since the feature matrix is simply a table of numerical values you can safely export it as csv file,
# or any other file format you like.

# %%
sfm.to_csv('../data/my_project.sfm')

# %% [markdown]
# Read the file again with:

# %%
sfm2 = pd.read_csv('../data/my_project.sfm', index_col=0)

# %%
sfm2
# Out:
#           centroid       spread  roughness      flux
# Song1  1914.788445  2111.326855   0.001577  2.577563
# Song2     0.114007     0.230311   0.010049  0.490908
# SOng3     0.200553     0.869713   0.622862  0.170603
